# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %%
observations=1000

xs=np.random.uniform(low=-10,high=10,size=(observations,1))
zs=np.random.uniform(-10,10,(observations,1))

inputs=np.column_stack((xs,zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %%
noise=np.random.uniform(-1,1,(observations,1))
targets=2*xs + 3*zs +5 +noise
print(targets.shape)
# Out:
# (1000, 1)

# %%
targets=targets.reshape(observations,)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(axim=0)
plt.show()
targets=targets.reshape(observations,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-38ee202c1212> in <module>
#       6 ax.set_ylabel('zs')
#       7 ax.set_zlabel('Targets')
# ----> 8 ax.view_init(axim=0)
#       9 plt.show()
#      10 targets=targets.reshape(observations,1)
#
# TypeError: view_init() got an unexpected keyword argument 'axim'

# %%
init_range=0.1
weights=np.random.uniform(-init_range,init_range,size=(2,1))
biases=np.random.uniform(-init_range,init_range,size=1)

print(weights)
print(biases)
# Out:
# [[-0.0691599 ]
#  [ 0.08005562]]
# [-0.0716367]

# %%
learning_rate=0.02

# %%
for i in range(100):
    outputs=np.dot(inputs,weights) + biases
    deltas=outputs-targets
    loss=np.sum(deltas**2)/2/observations
    
    print(loss)
    deltas_scaled=deltas/observations
    weights=weights-learning_rate*np.dot(inputs.T,deltas_scaled)
# Out:
# 233667.49187661792
# 233431.9969756923
# 233403.00448671638
# 233399.40297202795
# 233398.95218153973
# 233398.89540085781
# 233398.88821177153
# 233398.8872977149
# 233398.88718110247
# 233398.88716618498
# 233398.88716427254
# 233398.88716402705
# 233398.8871639955
# 233398.88716399146
# 233398.88716399082
# 233398.8871639908
# 233398.88716399082
# 233398.8871639908
# 233398.88716399076
# 233398.8871639907
# 233398.8871639908
# 233398.88716399076
# 233398.88716399085
# 233398.8871639908
# 233398.88716399076
# 233398.8871639908
# 233398.88716399088
# 233398.8871639907
# 233398.88716399067
# 233398.8871639908
# 233398.88716399076
# 233398.88716399073
# 233398.8871639907
# 233398.8871639907
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067
# 233398.88716399067

# %%
print(weights,biases)
# Out:
# [[-0.07588872 -0.00589512 -0.00754894 ...  0.00393749 -0.09583412
#   -0.11157218]
#  [ 0.01096702  0.00085193  0.00109093 ... -0.00056902  0.01384942
#    0.0161238 ]] [-0.0716367]
